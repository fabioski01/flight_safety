# %% [markdown]
# # Mission Analysis
#
# ## Identify the Type of Mission
# - **Launch Location**
# - **Orbit**
# - **Inclination**
#
# ## Key Events
# 1. Ignition S1
# 2. Ignition S2
# 3. Ignition S3
# 4. Max Q
# 5. MECO (Main Engine Cut-Off)
# 6. SECO (Second Engine Cut-Off)
# 7. Stage Separation 1/2
# 8. Fairing Separation
# 9. Payload Capability (assuming 200kg of dry mass for kick stage)
#
# ## Output Requirements
# - Time, position, and altitude of the key events, along with their relative impact points.
# - A separate folder containing the state vector at each event (stage and fairing separation).
#
# ## Optional Features
# - Generate KMZ or KML files for visualization in Google Earth of the trajectories and the line of instantaneous impact point.
# - Identify the "interesting" trajectory as a feature.
#
# ## Code Considerations
# - The size of the trajectory is not constant, similar to the information available. To maintain a lean codebase for different applications, consider this variability. Avoid extracting column X under the assumption that it will consistently contain the same information.

# %%
# Identify the type of mission (where do we launch, orbit, inclination). Then the key events:
#   ignition S1
#   ignition S2
#   ignition S3
#   max q
#   meco (main engine cut-off)
#   seco (second engine cut-off)
#   stage separation 1/2
#   fairing separation
#   payload capability assuming 200kg of dry mass for kick stage
# Have as an output the time, position and altitude of the key event and their relative impact point
# Having in a separate folder the state vector at each event (stage and fairing separation)
# Optional: could you generate kmz or kml files for visualization in google earth of the trajectories and the line of instantaneous impact point
# The “interesting” trajectory as a feature, will you be able to identify it?
# The size of the trajectory is not constant, same as the info available. In order to have a lean code that will be used for different application, consider this small feature and don’t extract column X thinking it will be the same info all the time 

from open_excel import load_excel
from functions_def import find_first_and_last_nonzero

file_path = '/home/fabiomeloni/flight_safety/traiettoria.xlsx'
df = load_excel(file_path)
print(df.shape)  # Check dimensions
print(df.head())  # Check first few rows
# Out:
# Loading Excel: 100%|██████████| 4645/4645 [00:20<00:00, 225.14rows/s]
# (4645, 482)
#                      0                                                  1    \
# 0                Column1                                            Column2
# 1                  Phase  acceleration_without_gravity_east~Rocket#L~Roc...
# 2            Phase Index  East Acceleration w/o Gravity of Rocket in L~R...
# 3                   None                                    Meter/Second**2
# 4   1.00000000000000E+00                               3.59557518061713E-17
#
#                                                  2    \
# 0                                            Column3
# 1  acceleration_without_gravity_north~Rocket#L~Ro...
# 2  North Acceleration w/o Gravity of Rocket in L~...
# 3                                    Meter/Second**2
# 4                              -5.20679030437857E-16
#
#                                                  3    \
# 0                                            Column4
# 1  acceleration_without_gravity_radial~Rocket#L~R...
# 2  Radial Acceleration w/o Gravity of Rocket in L...
# 3                                    Meter/Second**2
# 4                               1.18697251065212E+01
#
#                                                  4    \
# 0                                            Column5
# 1  acceleration_without_gravity_x~Rocket#B~Rocket...
# 2  X-Acceleration w/o Gravity of Rocket in B~Rock...
# 3                                    Meter/Second**2
# 4                               1.18697251065212E+01
#
#                                                  5    \
# 0                                            Column6
# 1  acceleration_without_gravity_y~Rocket#B~Rocket...
# 2  Y-Acceleration w/o Gravity of Rocket in B~Rock...
# 3                                    Meter/Second**2
# 4                              -1.25767452008319E-16
#
#                                                  6    \
# 0                                            Column7
# 1  acceleration_without_gravity_z~Rocket#B~Rocket...
# 2  Z-Acceleration w/o Gravity of Rocket in B~Rock...
# 3                                    Meter/Second**2
# 4                              -5.06539254985228E-16
#
#                                                  7    \
# 0                                            Column8
# 1                acceleration_without_gravity~Rocket
# 2  Norm of the Total Acceleration w/o Gravity of ...
# 3                                    Meter/Second**2
# 4                               1.18697251065212E+01
#
#                                           8    \
# 0                                     Column9
# 1           acceleration_x~Rocket#J2000@Earth
# 2  Acceleration X of Rocket in J2000 at Earth
# 3                             Meter/Second**2
# 4                       -1.49052258433866E-01
#
#                                           9    ...  \
# 0                                    Column10  ...
# 1           acceleration_y~Rocket#J2000@Earth  ...
# 2  Acceleration Y of Rocket in J2000 at Earth  ...
# 3                             Meter/Second**2  ...
# 4                        1.00098321907403E+00  ...
#
#                                                  472  \
# 0                                          Column473
# 1                 z_offset~Inert_Mass_Stage_3:Rocket
# 2  z-Offset of Bottom Node wrt Global Node of Ine...
# 3                                              Meter
# 4                               0.00000000000000E+00
#
#                                                  473  \
# 0                                          Column474
# 1                            z_offset~Stage_1:Rocket
# 2  z-Offset of Bottom Node wrt Global Node of Sta...
# 3                                              Meter
# 4                               0.00000000000000E+00
#
#                                                  474  \
# 0                                          Column475
# 1                            z_offset~Stage_2:Rocket
# 2  z-Offset of Bottom Node wrt Global Node of Sta...
# 3                                              Meter
# 4                               0.00000000000000E+00
#
#                                                  475  \
# 0                                          Column476
# 1                            z_offset~Stage_3:Rocket
# 2  z-Offset of Bottom Node wrt Global Node of Sta...
# 3                                              Meter
# 4                               0.00000000000000E+00
#
#                                                  476  \
# 0                                          Column477
# 1                 z_offset~Stage_Inert_Mass_1:Rocket
# 2  z-Offset of Bottom Node wrt Global Node of Sta...
# 3                                              Meter
# 4                               0.00000000000000E+00
#
#                                    477                            478  \
# 0                            Column478                      Column479
# 1                    z~Earth#J2000@SSB           z~Rocket#J2000@Earth
# 2  z-Position of Earth in J2000 at SSB  z of Rocket in J2000 at Earth
# 3                           Kilo-Meter                     Kilo-Meter
# 4                 5.75240387627703E+07           5.54665660601263E+03
#
#                                  479                                   480  \
# 0                          Column480                             Column481
# 1           z~Rocket#TOD~Earth@Earth           z~Sun#L~Rocket:Earth@Rocket
# 2  z of Rocket in TOD~Earth at Earth  z of Sun in L~Rocket:Earth at Rocket
# 3                         Kilo-Meter                            Kilo-Meter
# 4               5.54555203459506E+03                  8.95599724465286E+07
#
#                                     481
# 0                             Column482
# 1           z~Sun#L~Rocket:Earth@Rocket
# 2  z of Sun in L~Rocket:Earth at Rocket
# 3                            Kilo-Meter
# 4                  8.95599724465286E+07
#
# [5 rows x 482 columns]

# %%
# Specify the column name
column_name = "thrust~Engine_1_Up:Rocket"

# Find the first and last non-zero indices
first_index, last_index = find_first_and_last_nonzero(df, column_name)

print(f"First non-zero value at row index: {first_index}")
print(f"Last non-zero value at row index: {last_index}")
# Out:
# First non-zero value at row index: 4
# Last non-zero value at row index: 4644
